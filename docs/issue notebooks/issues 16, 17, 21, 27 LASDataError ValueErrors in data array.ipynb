# %%
fns = [r"D:\study\2015\las_kgs_test\2001_2005\1031902741.las",   # issue 16
       r"D:\study\2015\las_kgs_test\2001_2005\1031712032.las",   # issue 17
       r"D:\study\2015\las_kgs_test\1999\1999\1006346380.las",   # issue 21
       r"D:\study\2015\las_kgs_test\2014\1044907419.las",        # issue 27
       ]

# %%
import las_reader
import logging

# %%
for fn in fns:
    logging.warning(fn)
    l = las_reader.read(fn)
# Out:
# WARNING:root:D:\study\2015\las_kgs_test\2001_2005\1031902741.las
# WARNING:las_reader.las:  1600.000    222.649      3.777      2.846      2.697
#   1600.500    224.159      3.748      2.851      2.710
#   1601.000    227.391      3.724      2.869      2.718
#   1601.500    242.993      3.708      2.894      2.731
#   1602.000    259.205      3.800      2.914      2.752
#   1602.500    269.272      3.893      2.944      2.772
#   1603.000    281.113      3.949      2.969      2.798
#   1603.500    285.166      4.047      3.004      2.816
#   1604.000    286.225      4.066      3.004      2.838
#   1604.500    284.503      4.015      3.004      2.846
#   1605.000    277.457      3.960      2.986      2.846
#   1605.500    267.497      3.941      2.967      2.846
#   1606.000    263.868      3.914      2.967      2.846
#   1606.500    267.947      3.895      2.958      2.846
#   1607.000     -1.#IO     -1.#IO     -1.#IO     -1.#IO
# ...
